# %%
# !pip install dill
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# %%
os.chdir('/content/drive/My Drive/NLP-Letters-V2/notebooks/')

# %%
df = pd.read_csv('../data/conceptx_data/clusters-100.txt', sep='\|\|\|')
df.columns = ['Word', 'WordID', 'SentID', 'TokenID', 'ClusterID']
# Out:
# <ipython-input-61-ea21115f7d6c>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('../data/conceptx_data/clusters-100.txt', sep='\|\|\|')

# %%
df[df['ClusterID'] == 87][:50]
# Out:
#              Word WordID  SentID  TokenID  ClusterID
# 14273       while      1       3        0         87
# 14274           ’      1       3        2         87
# 14275           —      1       3       31         87
# 14276           —      2       3       38         87
# 14277       alice      1      11       18         87
# 14278        what      1      13       18         87
# 14279          to      9      13       26         87
# 14280         and     14      14        3         87
# 14281           ’      2      30       30         87
# 14282           ’      3      38        9         87
# 14283   personnel      1      39       21         87
# 14284           ’      4      40        7         87
# 14285        know      1      48        1         87
# 14286           ]      1      48       19         87
# 14287           ’      5      50       15         87
# 14288           “      1      51       10         87
# 14289           ”      1      51       16         87
# ...

# %%
df[df['Word'] == 'he']
# Out:
#       Word WordID  SentID  TokenID  ClusterID
# 10282   he      1       3       39         20
# 10284   he      2       5        4         20
# 10286   he      3       6       19         20
# 10288   he      5      13        6         20
# 10291   he      8      18        5         20
# ...    ...    ...     ...      ...        ...
# 11799   he    291     982        0         45
# 14486   he    130     451        0         87
# 14540   he    162     605        0         87
# 14636   he    260     877       16         87
# 19870   he     40     118       23         11
#
# [292 rows x 5 columns]
