# %%
import pandas as pd
import os
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/NLP-Letters-V2/notebooks/')
df1 = pd.read_csv('../data/letters_2021.csv')
df2 = pd.read_csv('../data/sentence_sets_trimmed.csv', encoding='mac-roman')
df2 = df2[df2['full_text_tokens'] > 10]

# %% [markdown]
# # First Dataset

# %%
identifier_pattern = r'(?:^|\b|[^\w\s]+)(first_name|identifier|last_name|middle_name)(?:\b|[^\w\s]+|$)'
pronoun_pattern = r"(?:^|\b|[^\w\s]+)(he|she|him|himself|herself|her|his|hers|he’s|she’s|he's|she's)(?:\b|[^\w\s]+|$)"

# %%
def classify_sentence(sentence):
    if re.search(identifier_pattern, sentence, re.IGNORECASE):
        return 's1'
    elif re.search(pronoun_pattern, sentence, re.IGNORECASE):
        return 's2'
    else:
        return 's3'

# %%
df1['sentences'] = df1['LETTERTEXT'].apply(nltk.sent_tokenize)

# %%
df1['s1'] = None
df1['s2'] = None
df1['s3'] = None
df1['s1_s2'] = None

for idx, row in df1.iterrows():
    s1_sentences = []
    s2_sentences = []
    s3_sentences = []
    s1_s2_sentences = []

    for sentence in row['sentences']:
        category = classify_sentence(sentence)
        if category == 's1':
            s1_sentences.append(sentence)
            s1_s2_sentences.append(sentence)
        elif category == 's2':
            s2_sentences.append(sentence)
            s1_s2_sentences.append(sentence)
        else:
            s3_sentences.append(sentence)

    df1.at[idx, 's1'] = ' '.join(s1_sentences)
    df1.at[idx, 's2'] = ' '.join(s2_sentences)
    df1.at[idx, 's3'] = ' '.join(s3_sentences)
    df1.at[idx, 's1_s2'] = ' '.join(s1_s2_sentences)

# %%
df1['full_text'] = df1['LETTERTEXT'].astype(str)
df1['full_text'] = df1['full_text'].str.lower()
df1['s1'] = df1['s1'].str.lower()
df1['s2'] = df1['s2'].str.lower()
df1['s3'] = df1['s3'].str.lower()
df1['s1_s2'] = df1['s1_s2'].str.lower()

# %%
df1
# Out:
#                                 MD5_ID  YEAR  LETTERNUM LETTER_GENDER  \
# 0     933e79d01a4aad7671a1120d6b5fddb5  2021          1             F
# 1     933e79d01a4aad7671a1120d6b5fddb5  2021          2             F
# 2     933e79d01a4aad7671a1120d6b5fddb5  2021          3             F
# 3     458e7ee7e1ba439d294123d18217ccc6  2021          1             F
# 4     458e7ee7e1ba439d294123d18217ccc6  2021          2             F
# ...                                ...   ...        ...           ...
# 5702  4948148cd84320b7c3ca41743f860465  2021          3             F
# 5703  4948148cd84320b7c3ca41743f860465  2021          4             F
# 5704  003f1558964ebd71b9dbba552a815b90  2021          1             F
# 5705  003f1558964ebd71b9dbba552a815b90  2021          2             F
# 5706  003f1558964ebd71b9dbba552a815b90  2021          3             F
#
#                                              LETTERTEXT  \
# 0     It is my pleasure to write a letter of recomme...
# 1     I am pleased to highly recommend IDENTIFIER fo...
# 2     I am writing this letter in support of IDENTIF...
# 3     IDENTIFIER IDENTIFIER recently completed an an...
# 4     It is my pleasure to recommend Dr. IDENTIFIER ...
# ...                                                 ...
# 5702  It is with great pleasure that I recommend med...
# 5703  IDENTIFIER is an enthusiastic young woman who ...
# 5704  A pleasure to work with” ERAS Application Seas...
# 5705  It is with great pleasure that I write a lette...
# 5706  [POSSIBLE_IDENTIFIER: IDENTIFIER AAMC ID: IDEN...
#
#                                         GENDERLESS_TEXT  \
# 0     It is my pleasure to write a letter of recomme...
# 1     I am pleased to highly recommend IDENTIFIER fo...
# 2     I am writing this letter in support of IDENTIF...
# 3     IDENTIFIER IDENTIFIER recently completed an an...
# 4     It is my pleasure to recommend Dr. IDENTIFIER ...
# ...                                                 ...
# 5702  It is with great pleasure that I recommend med...
# 5703  IDENTIFIER is an enthusiastic young woman who ...
# 5704  A pleasure to work with” ERAS Application Seas...
# 5705  It is with great pleasure that I write a lette...
# 5706  [POSSIBLE_IDENTIFIER: IDENTIFIER AAMC ID: IDEN...
#
#                                               sentences  \
# 0     [It is my pleasure to write a letter of recomm...
# 1     [I am pleased to highly recommend IDENTIFIER f...
# 2     [I am writing this letter in support of IDENTI...
# 3     [IDENTIFIER IDENTIFIER recently completed an a...
# 4     [It is my pleasure to recommend Dr. IDENTIFIER...
# ...                                                 ...
# 5702  [It is with great pleasure that I recommend me...
# 5703  [IDENTIFIER is an enthusiastic young woman who...
# 5704  [A pleasure to work with” ERAS Application Sea...
# 5705  [It is with great pleasure that I write a lett...
# 5706  [[POSSIBLE_IDENTIFIER: IDENTIFIER AAMC ID: IDE...
#
#                                                      s1  \
# 0     it is my pleasure to write a letter of recomme...
# 1     i am pleased to highly recommend identifier fo...
# 2     i am writing this letter in support of identif...
# 3     identifier identifier recently completed an an...
# 4     it is my pleasure to recommend dr. identifier ...
# ...                                                 ...
# 5702  it is with great pleasure that i recommend med...
# 5703  identifier is an enthusiastic young woman who ...
# 5704  a pleasure to work with” eras application seas...
# 5705  it is with great pleasure that i write a lette...
# 5706  [possible_identifier: identifier aamc id: iden...
#
#                                                      s2  \
# 0     her pleasing personality and sincere dedicatio...
# 1     she is a quick learner who grasped the materia...
# 2
# 3     i have found her to always be professional and...
# 4     although it was the first rotation of her tran...
# ...                                                 ...
# 5702  her performance was truly outstanding. she was...
# 5703  she was referred to me due to her interest in ...
# 5704  of note, she has already accomplished several ...
# 5705  she has a left a very strong impression during...
# 5706  she is detail oriented, an outstanding problem...
#
#                                                      s3  \
# 0
# 1     i have worked at jamaica hospital medical cent...
# 2
# 3     if you have any questions, please do not hesit...
# 4
# ...                                                 ...
# 5702  i often assign topics to present to the medica...
# 5703  under my mentorship, we planned our publicatio...
# 5704  these include helping in the conceptualization...
# 5705  if you have any further questions, please don’...
# 5706
#
#                                                   s1_s2  \
# 0     it is my pleasure to write a letter of recomme...
# 1     i am pleased to highly recommend identifier fo...
# 2     i am writing this letter in support of identif...
# 3     identifier identifier recently completed an an...
# 4     it is my pleasure to recommend dr. identifier ...
# ...                                                 ...
# 5702  it is with great pleasure that i recommend med...
# 5703  identifier is an enthusiastic young woman who ...
# 5704  a pleasure to work with” eras application seas...
# 5705  it is with great pleasure that i write a lette...
# 5706  [possible_identifier: identifier aamc id: iden...
#
#                                               full_text
# 0     it is my pleasure to write a letter of recomme...
# 1     i am pleased to highly recommend identifier fo...
# 2     i am writing this letter in support of identif...
# 3     identifier identifier recently completed an an...
# 4     it is my pleasure to recommend dr. identifier ...
# ...                                                 ...
# 5702  it is with great pleasure that i recommend med...
# 5703  identifier is an enthusiastic young woman who ...
# 5704  a pleasure to work with” eras application seas...
# 5705  it is with great pleasure that i write a lette...
# 5706  [possible_identifier: identifier aamc id: iden...
#
# [5707 rows x 12 columns]

# %% [markdown]
# # Second Dataset

# %%
df2['sentences'] = df2['TEXT'].apply(nltk.sent_tokenize)

# %%
df2['s1'] = None
df2['s2'] = None
df2['s3'] = None
df2['s1_s2'] = None

for idx, row in df2.iterrows():
    s1_sentences = []
    s2_sentences = []
    s3_sentences = []
    s1_s2_sentences = []

    for sentence in row['sentences']:
        category = classify_sentence(sentence)
        if category == 's1':
            s1_sentences.append(sentence)
            s1_s2_sentences.append(sentence)
        elif category == 's2':
            s2_sentences.append(sentence)
            s1_s2_sentences.append(sentence)
        else:
            s3_sentences.append(sentence)

    df2.at[idx, 's1'] = ' '.join(s1_sentences)
    df2.at[idx, 's2'] = ' '.join(s2_sentences)
    df2.at[idx, 's3'] = ' '.join(s3_sentences)
    df2.at[idx, 's1_s2'] = ' '.join(s1_s2_sentences)

# %%
df2['full_text'] = df2['TEXT'].astype(str)
df2['full_text'] = df2['full_text'].str.lower()
df2['s1'] = df2['s1'].str.lower()
df2['s2'] = df2['s2'].str.lower()
df2['s3'] = df2['s3'].str.lower()
df2['s1_s2'] = df2['s1_s2'].str.lower()

# %%
df2
# Out:
#      applicant_id                document writer_gender letter_type  \
# 0       male_3090  sentence_sets.csv.4358        female         lor
# 1      female_267  sentence_sets.csv.4301          male         lor
# 2       male_1004   sentence_sets.csv.179          male         lor
# 3      female_147  sentence_sets.csv.3846          male         lor
# 4        male_381     sentence_sets.csv.6        female         lor
# ...           ...                     ...           ...         ...
# 3280    female_29  sentence_sets.csv.3354          male       chair
# 3281   female_292  sentence_sets.csv.4395        female         lor
# 3282     male_651  sentence_sets.csv.1013          male         lor
# 3283    male_1930  sentence_sets.csv.2528          male         lor
# 3284    male_2844  sentence_sets.csv.4006          male         lor
#
#      applicant_gender                                 applicant_identify  \
# 0                male                                              white
# 1              female                                    asian - chinese
# 2                male  hispanic, latino, or of spanish origin - mexic...
# 3              female  hispanic, latino, or of spanish origin - other...
# 4                male  black or african american - african american|b...
# ...               ...                                                ...
# 3280           female                                    asian - chinese
# 3281           female                                    asian - chinese
# 3282             male                                    asian - chinese
# 3283             male                                    asian - chinese
# 3284             male                                    asian - chinese
#
#        applicant_identify_group  standardized_lor  us_canadian  usmle_1  \
# 0                         white                 1            1      197
# 1                         asian                 1            1      203
# 2       hispanic_latino_spanish                 1            1      206
# 3       hispanic_latino_spanish                 1            1      206
# 4     black or african american                 1            1      210
# ...                         ...               ...          ...      ...
# 3280                      asian                 0            1      273
# 3281                      asian                 0            1      273
# 3282                      asian                 0            1      274
# 3283                      asian                 0            1      274
# 3284                      asian                 0            1      274
#
#       usmle_2 applicants_writers  \
# 0         225        male_female
# 1         227        female_male
# 2         237          male_male
# 3         217        female_male
# 4         225        male_female
# ...       ...                ...
# 3280      261        female_male
# 3281      261      female_female
# 3282      277          male_male
# 3283      277          male_male
# 3284      277          male_male
#
#                                                    TEXT  \
# 0     this letter serves as the department of medici...
# 1     this letter is written in support of FIRST_NAM...
# 2     comments from anesthesiology rotations : ‚Äú F...
# 3     long number ms LAST_NAME had originally planne...
# 4     ‚Äú i think [ FIRST_NAME ] would be an asset t...
# ...                                                 ...
# 3280  it is with pleasure that i recommend FIRST_NAM...
# 3281  we are very pleased to write this letter based...
# 3282  | am writing this letter of recommendation for...
# 3283  it is my pleasure to write FIRST_NAME support ...
# 3284  please accept my strongest recommendation for ...
#
#                                               full_text  \
# 0     this letter serves as the department of medici...
# 1     this letter is written in support of first_nam...
# 2     comments from anesthesiology rotations : ‚äú f...
# 3     long number ms last_name had originally planne...
# 4     ‚äú i think [ first_name ] would be an asset t...
# ...                                                 ...
# 3280  it is with pleasure that i recommend first_nam...
# 3281  we are very pleased to write this letter based...
# 3282  | am writing this letter of recommendation for...
# 3283  it is my pleasure to write first_name support ...
# 3284  please accept my strongest recommendation for ...
#
#                                                      s1  \
# 0     first_name last_name . last_name waived his ri...
# 1     this letter is written in support of first_nam...
# 2     comments from anesthesiology rotations : ‚äú f...
# 3     long number ms last_name had originally planne...
# 4     ‚äú i think [ first_name ] would be an asset t...
# ...                                                 ...
# 3280  it is with pleasure that i recommend first_nam...
# 3281  we are very pleased to write this letter based...
# 3282  | am writing this letter of recommendation for...
# 3283  it is my pleasure to write first_name support ...
# 3284  please accept my strongest recommendation for ...
#
#                                                      s2  \
# 0     his presentations were detailed oriented , wri...
# 1     by milestone assessment , her areas of strengt...
# 2     he had excellent questions to showed his since...
# 3     she took full advantage of the opportunity , f...
# 4     he's someone | look forward to speaking with a...
# ...                                                 ...
# 3280  she was interested during rounds in all patien...
# 3281  she has waived her right to see this letter . ...
# 3282  during his four weeks he rotated through traum...
# 3283  the fellow he was working with and i were extr...
# 3284  he was extremely motivated , hardworking , and...
#
#                                                   s1_s2  \
# 0     first_name last_name . last_name waived his ri...
# 1     this letter is written in support of first_nam...
# 2     comments from anesthesiology rotations : ‚äú f...
# 3     long number ms last_name had originally planne...
# 4     ‚äú i think [ first_name ] would be an asset t...
# ...                                                 ...
# 3280  it is with pleasure that i recommend first_nam...
# 3281  we are very pleased to write this letter based...
# 3282  | am writing this letter of recommendation for...
# 3283  it is my pleasure to write first_name support ...
# 3284  please accept my strongest recommendation for ...
#
#                                                      s3  full_text_tokens  \
# 0     this letter serves as the department of medici...               526
# 1     our residents rotate in both inpatient and amb...               447
# 2     ‚äù ‚äú works hard , always looking for ways t...               365
# 3     ( 2 ) | am not aware of any areas that require...               346
# 4     ucsd would be fortunate to get to keep this fu...               512
# ...                                                 ...               ...
# 3280  the medical icu rotation is a demanding rotati...               199
# 3281  ms . ms . . . . . . . and was always seeking f...               820
# 3282  please do not hesitate to contact me if you ha...               288
# 3283  i am writing this letter to give my highest po...               551
# 3284  if you have any questions , please do not hesi...               247
#
#                                               sentences
# 0     [this letter serves as the department of medic...
# 1     [this letter is written in support of FIRST_NA...
# 2     [comments from anesthesiology rotations : ‚Äú ...
# 3     [long number ms LAST_NAME had originally plann...
# 4     [‚Äú i think [ FIRST_NAME ] would be an asset ...
# ...                                                 ...
# 3280  [it is with pleasure that i recommend FIRST_NA...
# 3281  [we are very pleased to write this letter base...
# 3282  [| am writing this letter of recommendation fo...
# 3283  [it is my pleasure to write FIRST_NAME support...
# 3284  [please accept my strongest recommendation for...
#
# [3280 rows x 20 columns]

# %% [markdown]
# # Combine Datasets

# %%
df1 = df1[['s1_s2', 'full_text', 'LETTER_GENDER']]
df1 = df1.rename(columns={'LETTER_GENDER':'label'})
df2 = df2[['s1_s2', 'full_text', 'applicant_gender']]
df2 = df2.rename(columns={'applicant_gender':'label'})

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
gender_label_mapping = {
    'F':0,
    'female':0,
    'M':1,
    'male':1
}

# %%
df['label'] = df['label'].replace(gender_label_mapping)
# Out:
# <ipython-input-17-cc45885305bc>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['label'] = df['label'].replace(gender_label_mapping)

# %%
df
# Out:
#                                                   s1_s2  \
# 0     it is my pleasure to write a letter of recomme...
# 1     i am pleased to highly recommend identifier fo...
# 2     i am writing this letter in support of identif...
# 3     identifier identifier recently completed an an...
# 4     it is my pleasure to recommend dr. identifier ...
# ...                                                 ...
# 8982  it is with pleasure that i recommend first_nam...
# 8983  we are very pleased to write this letter based...
# 8984  | am writing this letter of recommendation for...
# 8985  it is my pleasure to write first_name support ...
# 8986  please accept my strongest recommendation for ...
#
#                                               full_text  label
# 0     it is my pleasure to write a letter of recomme...      0
# 1     i am pleased to highly recommend identifier fo...      0
# 2     i am writing this letter in support of identif...      0
# 3     identifier identifier recently completed an an...      0
# 4     it is my pleasure to recommend dr. identifier ...      0
# ...                                                 ...    ...
# 8982  it is with pleasure that i recommend first_nam...      0
# 8983  we are very pleased to write this letter based...      0
# 8984  | am writing this letter of recommendation for...      1
# 8985  it is my pleasure to write first_name support ...      1
# 8986  please accept my strongest recommendation for ...      1
#
# [8987 rows x 3 columns]

# %%
# df.to_csv('../data/df_sentences_with_gender.csv', index=False)
