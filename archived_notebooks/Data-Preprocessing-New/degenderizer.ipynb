# %%
import pandas as pd
import numpy as np
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/NLP-Letters-V2/notebooks/')
df1 = pd.read_csv('../data/letters_2021.csv')
df2 = pd.read_csv('../data/sentence_sets_trimmed.csv', encoding='mac-roman')
df2 = df2[df2['full_text_tokens'] > 10]

# %%
raw_pairs = {}
with open("../data/gendered_term_list.txt", "r", encoding="utf-8") as f:
    for line in f:
        key, value = line.strip().split("\t")
        raw_pairs[key] = value

# %%
# raw_pairs

# %% [markdown]
# # Preprocess Data

# %%
degender_mapping = {
    rf"(?:^|\b|[^\w\s])(?P<token>{re.escape(k)})(?P<suffix>'s|’s)?(?=\b|[^\w\s]|$)": v
    for k, v in raw_pairs.items()
}

# %%
degender_mapping
# Out:
# {"(?:^|\\b|[^\\w\\s])(?P<token>masculine)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'feminine',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masculinely)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'femininely',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masculinity)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'femininity',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masculism)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'feminism',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masculinist)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'feminist',
#  "(?:^|\\b|[^\\w\\s])(?P<token>patriarch)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'matriarch',
#  "(?:^|\\b|[^\\w\\s])(?P<token>patriarchal)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'matriarchal',
#  "(?:^|\\b|[^\\w\\s])(?P<token>male)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'female',
#  "(?:^|\\b|[^\\w\\s])(?P<token>males)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'females',
#  "(?:^|\\b|[^\\w\\s])(?P<token>maleness)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'femaleness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gamine)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boyhood)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlhood',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boyish)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlish',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boyishly)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlishly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boyishness)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlishness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>man)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'woman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>men)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'women',
#  "(?:^|\\b|[^\\w\\s])(?P<token>manhood)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'womanhood',
#  "(?:^|\\b|[^\\w\\s])(?P<token>manliness)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'womanliness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>manly)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'womanly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>virile)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'uxorially',
#  "(?:^|\\b|[^\\w\\s])(?P<token>virility)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'milkiness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sir)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'madam',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sirs)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'madams',
#  "(?:^|\\b|[^\\w\\s])(?P<token>widower)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'widow',
#  "(?:^|\\b|[^\\w\\s])(?P<token>widowers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'widows',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mr)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ms',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mister)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ms',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gentleman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'damsel',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gentlemen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'damsels',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gentlemanlike)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ladylike',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lord)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lady',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lords)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ladies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>groom)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bride',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grooms)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'brides',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bridegroom)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bride',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bridegrooms)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'brides',
#  "(?:^|\\b|[^\\w\\s])(?P<token>best\\ man)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bridesmaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>best\\ men)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bridesmaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fiance)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fiancee',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fiancé)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fiancée',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fiances)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fiancees',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fiancés)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fiancées',
#  "(?:^|\\b|[^\\w\\s])(?P<token>housewifely)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'butch',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bloke)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>blokes)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dude)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlie',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dudes)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fella)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'chick',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fellas)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'chicks',
#  "(?:^|\\b|[^\\w\\s])(?P<token>chap)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lassie',
#  "(?:^|\\b|[^\\w\\s])(?P<token>chaps)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lassies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>guy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'gal',
#  "(?:^|\\b|[^\\w\\s])(?P<token>guys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'gals',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lad)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lass',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lads)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lasses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>macho)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'diva',
#  "(?:^|\\b|[^\\w\\s])(?P<token>machos)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'divas',
#  "(?:^|\\b|[^\\w\\s])(?P<token>actor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'actress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>actors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'actresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>waiter)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'waitress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>waiters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'waitresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>king)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'queen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kings)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'queens',
#  "(?:^|\\b|[^\\w\\s])(?P<token>prince)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'princess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>princes)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'princesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>monk)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nun',
#  "(?:^|\\b|[^\\w\\s])(?P<token>monks)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nuns',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brethren)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nuns',
#  "(?:^|\\b|[^\\w\\s])(?P<token>monastery)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'convent',
#  "(?:^|\\b|[^\\w\\s])(?P<token>friary)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nunnery',
#  "(?:^|\\b|[^\\w\\s])(?P<token>count)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'countess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>counts)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'countesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>wizard)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'witch',
#  "(?:^|\\b|[^\\w\\s])(?P<token>wizards)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'witches',
#  "(?:^|\\b|[^\\w\\s])(?P<token>priest)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'priestess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>priests)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'priestesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>prophet)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'prophetess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>prophets)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'prophetesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>patron)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'patroness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>patrons)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'patronesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>host)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hostess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>hosts)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hostesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>viscount)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'viscountess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>viscounts)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'viscountesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>shepherd)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'shepherdess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>shepherds)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'shepherdesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>steward)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stewardess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stewards)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stewardesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>heir)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'heiress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>heirs)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'heiresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>baron)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'baroness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>barons)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'baronesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>abbot)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'abbess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>abbots)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'abbesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>emperor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'empress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>emperors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'empresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>traitor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'traitress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>traitors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'traitresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>duke)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'duchess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dukes)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'duchesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>enchanter)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'enchantress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>enchanters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'enchantresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>songster)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'songstress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>songsters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'songstresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>hero)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'heroine',
#  "(?:^|\\b|[^\\w\\s])(?P<token>heroes)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'heroines',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sultan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sultana',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sultans)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sultanas',
#  "(?:^|\\b|[^\\w\\s])(?P<token>czar)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'czarina',
#  "(?:^|\\b|[^\\w\\s])(?P<token>czars)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'czarinas',
#  "(?:^|\\b|[^\\w\\s])(?P<token>signor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'signora',
#  "(?:^|\\b|[^\\w\\s])(?P<token>signors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'signoras',
#  "(?:^|\\b|[^\\w\\s])(?P<token>benefactor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'benefactress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>benefactors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'benefactresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>hunter)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'huntress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>tempter)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'temptress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>tempters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'temptresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>master)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mistress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mistresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>manservant)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maidservant',
#  "(?:^|\\b|[^\\w\\s])(?P<token>manservants)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maidservants',
#  "(?:^|\\b|[^\\w\\s])(?P<token>landlord)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'landlady',
#  "(?:^|\\b|[^\\w\\s])(?P<token>landlords)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'landladies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>countryman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'countrywoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>countrymen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'countrywomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>milkman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'milkmaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>milkmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'milkmaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>giant)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'giantess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>giants)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'giantesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mayor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mayoress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mayors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mayoresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>conductor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'conductress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>conductors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'conductresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>god)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'goddess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gods)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'goddesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>merman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mermaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mermen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mermaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>oarsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'oarswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>oarsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'oarswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bellboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'chambermaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bellboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'chambermaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dairyman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'dairymaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dairymen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'dairymaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>schoolmaster)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'schoolmistress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>schoolmasters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'schoolmistresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>headmaster)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'headmistress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>proprietor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'proprietress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>proprietors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'proprietresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ambassador)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ambassadress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ambassadors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ambassadresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adventurer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'adventuress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adventurers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'adventuresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>protector)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'protectress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>protectors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'protectresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>seducer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'seductress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>seducers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'seductresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sculptor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sculptress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sculptors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sculptresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>congressman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'congresswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>congressmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'congresswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sorcerer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sorceress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sorcerers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sorceresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>launderer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'laundress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>launderers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'laundresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>anchorite)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'anchoress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>anchorites)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'anchoresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>procurer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'procuress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>procurers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'procuresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>elector)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'electress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>electors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'electresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adulterer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'adulteress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adulterers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'adulteresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>doorman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'doorwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>doormen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'doorwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>policeman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'policewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>policemen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'policewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fireman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'firewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>firemen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'firewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>businessman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'businesswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>businessmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'businesswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>barman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'barmaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>barmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'barmaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mailman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mailwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mailmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mailwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>postman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'postwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>postmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'postwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>salesman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'saleswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>salesmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'saleswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>cowboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'cowgirl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>cowboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'cowgirls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>schoolboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'schoolgirl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>schoolboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'schoolgirls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>chairman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'chairwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>chairmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'chairwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>englishman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'englishwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>englishmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'englishwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>spokesman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'spokeswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>spokesmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'spokeswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>councilman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'councilwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>councilmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'councilwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>choirboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'choirgirl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>choirboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'choirgirls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>playboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'playgirl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>playboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'playgirls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>homeboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'homegirl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>homeboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'homegirls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>madman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'madwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>madmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'madwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>anchorman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'anchorwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>anchormen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'anchorwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sportsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sportswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sportsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sportswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>cameraman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'camerawoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>cameramen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'camerawomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fisherman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fisherwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fishermen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fisherwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>serviceman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'servicewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>servicemen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'servicewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>churchman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'churchwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>churchmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'churchwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>clergyman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'clergywoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>clergymen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'clergywomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>craftsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'craftswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>craftsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'craftswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>superman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'superwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>supermen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'superwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>nobleman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'noblewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>noblemen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'noblewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>horseman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'horsewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>horsemen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'horsewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stuntman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stuntwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stuntmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stuntwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>townsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'townswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>townsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'townswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>statesman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stateswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>statesmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stateswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>foreman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'forewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>foremen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'forewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kinsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'kinswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kinsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'kinswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bondman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bondwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bondmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bondwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bondsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bondswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bondsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'bondswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>handyman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'handywoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>handymen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'handywomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>henchman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'handmaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>henchmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'handmaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>strongman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'strongwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>strongmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'strongwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>charman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'charwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>charmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'charwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>tailor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'needlewoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>tailors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'needlewomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>newsman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newswoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>newsmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newswomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>father)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mother',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fathers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mothers',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brother)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sister',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brothers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sisters',
#  "(?:^|\\b|[^\\w\\s])(?P<token>husband)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'wife',
#  "(?:^|\\b|[^\\w\\s])(?P<token>husbands)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'wives',
#  "(?:^|\\b|[^\\w\\s])(?P<token>housewife)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'househusband',
#  "(?:^|\\b|[^\\w\\s])(?P<token>housewives)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'househusbands',
#  "(?:^|\\b|[^\\w\\s])(?P<token>hubby)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'wifey',
#  "(?:^|\\b|[^\\w\\s])(?P<token>hubbies)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'wifeys',
#  "(?:^|\\b|[^\\w\\s])(?P<token>son)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'daughter',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sons)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'daughters',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dad)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mom',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dads)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'moms',
#  "(?:^|\\b|[^\\w\\s])(?P<token>papa)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mama',
#  "(?:^|\\b|[^\\w\\s])(?P<token>papas)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mamas',
#  "(?:^|\\b|[^\\w\\s])(?P<token>daddy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mommy',
#  "(?:^|\\b|[^\\w\\s])(?P<token>daddies)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mommies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>pa)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ma',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paternity)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maternity',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paternally)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maternally',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paternal)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maternal',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fatherhood)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'motherhood',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brotherhood)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sisterhood',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fraternity)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sorority',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fraternities)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sororities',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fraternal)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sisterly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fraternally)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sisterly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brotherly)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sisterly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fatherly)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'motherly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandfatherly)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'grandmotherly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fathered)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mothered',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stepfather)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stepmother',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stepfathers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stepmothers',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stepbrother)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stepsister',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stepbrothers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stepsisters',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stepson)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stepdaughter',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stepsons)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'stepdaughters',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandfather)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'grandmother',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandfathers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'grandmothers',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandpa)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'grandma',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandpas)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'grandmas',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandson)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'granddaughter',
#  "(?:^|\\b|[^\\w\\s])(?P<token>grandsons)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'granddaughters',
#  "(?:^|\\b|[^\\w\\s])(?P<token>nephew)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'niece',
#  "(?:^|\\b|[^\\w\\s])(?P<token>nephews)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nieces',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brother\\-in\\-law)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sister-in-law',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brothers\\-in\\-law)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'sisters-in-law',
#  "(?:^|\\b|[^\\w\\s])(?P<token>father\\-in\\-law)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mother-in-law',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fathers\\-in\\-law)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mothers-in-law',
#  "(?:^|\\b|[^\\w\\s])(?P<token>son\\-in\\-law)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'daughter-in-law',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sons\\-in\\-law)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'daughters-in-law',
#  "(?:^|\\b|[^\\w\\s])(?P<token>uncle)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'aunt',
#  "(?:^|\\b|[^\\w\\s])(?P<token>uncles)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'aunts',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boyfriend)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlfriend',
#  "(?:^|\\b|[^\\w\\s])(?P<token>boyfriends)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'girlfriends',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ancestor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ancestress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ancestors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ancestresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bachelor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maiden',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bachelors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maidens',
#  "(?:^|\\b|[^\\w\\s])(?P<token>testosterone)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'estrogen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>testosterones)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'estrogens',
#  "(?:^|\\b|[^\\w\\s])(?P<token>penis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'vagina',
#  "(?:^|\\b|[^\\w\\s])(?P<token>penises)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'vaginas',
#  "(?:^|\\b|[^\\w\\s])(?P<token>prostate)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ovarian',
#  "(?:^|\\b|[^\\w\\s])(?P<token>testicles)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'uteruses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>testicle)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'uterus',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sperm)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ovary',
#  "(?:^|\\b|[^\\w\\s])(?P<token>he)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'she',
#  "(?:^|\\b|[^\\w\\s])(?P<token>him)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'her',
#  "(?:^|\\b|[^\\w\\s])(?P<token>his)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'her',
#  "(?:^|\\b|[^\\w\\s])(?P<token>himself)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'herself',
#  "(?:^|\\b|[^\\w\\s])(?P<token>he'd)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": "she'd",
#  "(?:^|\\b|[^\\w\\s])(?P<token>he'll)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": "she'll",
#  "(?:^|\\b|[^\\w\\s])(?P<token>gay)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lesbian',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gays)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lesbians',
#  "(?:^|\\b|[^\\w\\s])(?P<token>homosexuality)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lesbianism',
#  "(?:^|\\b|[^\\w\\s])(?P<token>victor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'victress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>victors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'victresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>murderer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'murderess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>murderers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'murderesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>millionaire)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'millionairess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>millionaires)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'millionairesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>manager)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'manageress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>managers)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'manageresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>governor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'governoress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>governors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'governoresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>director)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'directress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>directors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'directresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>inventor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'inventress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>inventors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'inventresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>instructor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'instructress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>instructors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'instructresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>childminder)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nursemaid',
#  "(?:^|\\b|[^\\w\\s])(?P<token>childminders)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'nursemaids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>barbershop)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hairdresser',
#  "(?:^|\\b|[^\\w\\s])(?P<token>beard)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hair',
#  "(?:^|\\b|[^\\w\\s])(?P<token>beards)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hair',
#  "(?:^|\\b|[^\\w\\s])(?P<token>juryman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'juror',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jurymen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'jurors',
#  "(?:^|\\b|[^\\w\\s])(?P<token>newsboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newspaper carrier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>newsboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newspaper carriers',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paperboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newspaper carrier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paperboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newspaper carriers',
#  "(?:^|\\b|[^\\w\\s])(?P<token>newspaperman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newspaperwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>newspapermen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'newspaperwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>divo)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'diva',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brideprice)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'dowry',
#  "(?:^|\\b|[^\\w\\s])(?P<token>airmen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'airwomen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>andropause)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'menopause',
#  "(?:^|\\b|[^\\w\\s])(?P<token>househusbands)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'housewives',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adultors)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'adultresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>andrology)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'obstetrics',
#  "(?:^|\\b|[^\\w\\s])(?P<token>marquis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'marchioness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stallion)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mare',
#  "(?:^|\\b|[^\\w\\s])(?P<token>semen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'female_ejaculation',
#  "(?:^|\\b|[^\\w\\s])(?P<token>androgen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'estrogen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>godfather)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'godmother',
#  "(?:^|\\b|[^\\w\\s])(?P<token>cialis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'viagra',
#  "(?:^|\\b|[^\\w\\s])(?P<token>beau)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'belle',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stud)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'minx',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bull)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'cow',
#  "(?:^|\\b|[^\\w\\s])(?P<token>beaus)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'belles',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adultor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'adultress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>rooster)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hen',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ballet_dancer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ballerina',
#  "(?:^|\\b|[^\\w\\s])(?P<token>colts)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'fillies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>suitor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'suitress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masseurs)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'masseuses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>deer)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'doe',
#  "(?:^|\\b|[^\\w\\s])(?P<token>busboys)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'busgirls',
#  "(?:^|\\b|[^\\w\\s])(?P<token>studs)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'minxes',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mentleman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lady',
#  "(?:^|\\b|[^\\w\\s])(?P<token>baritone)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mezzo',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paramour)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mistress',
#  "(?:^|\\b|[^\\w\\s])(?P<token>male_host)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hostess',
#  "(?:^|\\b|[^\\w\\s])(?P<token>menservants)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'maids',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mr\\.)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mrs.',
#  "(?:^|\\b|[^\\w\\s])(?P<token>headmasters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'headmistresses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>airman)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'airwoman',
#  "(?:^|\\b|[^\\w\\s])(?P<token>househusband)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'housewife',
#  "(?:^|\\b|[^\\w\\s])(?P<token>colt)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'filly',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lions)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lionesses',
#  "(?:^|\\b|[^\\w\\s])(?P<token>masseur)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'masseuse',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bulls)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'cows',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lion)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'lioness',
#  "(?:^|\\b|[^\\w\\s])(?P<token>prostatic_utricle)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'womb',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gents)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'ladies',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gelding)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'mare',
#  "(?:^|\\b|[^\\w\\s])(?P<token>roosters)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'hens',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stailor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": "seamstress'",
#  "(?:^|\\b|[^\\w\\s])(?P<token>busboy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'busgirl',
#  "(?:^|\\b|[^\\w\\s])(?P<token>heros)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'heroines',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bryan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>james)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sally)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gabriel)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jerome)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>carlos)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>devin)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dustin)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sara)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>frank)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>susan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>vernon)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ashley)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>christopher)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>scott)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>elizabeth)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>robert)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>helen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>steven)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>eric)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sean)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>craig)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>clifford)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>evan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dave)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jeremy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>rick)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>joel)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>michael)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>joseph)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>fred)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adam)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>alex)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>irene)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>donald)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>shane)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kyle)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>eugene)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kendra)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>rafael)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>laurie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paige)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>katie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kane)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>michelle)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>earl)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>dylan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bridget)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>adams)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>clark)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>corey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brad)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jacob)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stuart)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ari)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mark)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gary)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jeff)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jean)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>barrett)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>julius)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>anne)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>richard)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jerry)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jeffrey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>amanda)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jay)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jason)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>anthony)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ron)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>alfred)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>neil)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>peter)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>catherine)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gwen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>erin)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>julie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>allison)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>steve)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>aaron)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bradley)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>carolyn)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>deborah)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jack)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>todd)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>christine)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>max)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>casey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>warren)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>emma)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ronald)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>harold)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ali)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mohammad)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>noah)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>alison)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>stacey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>cameron)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>nick)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>nate)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>samuel)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gregory)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>deana)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lewis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>wilt)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>laura)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lucas)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>thomas)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>wilson)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>amy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kenneth)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brandon)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>brian)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kim)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>luis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paula)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>eduardo)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bailey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>leslie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>rob)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>roy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>don)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>david)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>andrew)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>alexander)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>carter)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>celia)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sam)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>paul)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>christie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>spence)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bruce)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bobby)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>tobin)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>carl)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>javier)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>kevin)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>gina)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>larry)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>alan)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>carey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>albert)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>reese)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>john)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>graham)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>beck)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>malcolm)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>olivia)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jess)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>eddie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jefferson)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>arnold)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>patrick)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ann)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>joe)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>mohamed)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>courtney)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>eli)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>edward)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>daniel)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>matthew)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>sarah)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ralph)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>chad)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>curtis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>charles)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>raj)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>alice)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>ricardo)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>clint)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>randolph)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>george)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>davis)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jesse)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>taylor)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>andy)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>elias)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>quinn)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>harvey)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>simon)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>emilia)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>harrison)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>allen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>rodney)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jon)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>bob)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>marie)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>william)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>zach)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>franklin)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>lindsay)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jeanine)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier',
#  "(?:^|\\b|[^\\w\\s])(?P<token>jereen)(?P<suffix>'s|’s)?(?=\\b|[^\\w\\s]|$)": 'identifier'}

# %%
df1 = df1[['LETTERTEXT', 'LETTER_GENDER']]
df1 = df1.rename(columns={'LETTERTEXT':'full_text', 'LETTER_GENDER':'label'})
df1['full_text'] = df1['full_text'].str.lower()

# %%
def apply_degendering(text):
    for pattern, replacement in degender_mapping.items():
        def repl(match):
            token = match.group("token")
            suffix = match.group("suffix") or ""
            replacement_base = raw_pairs.get(token.lower(), token)
            return match.group(0).replace(token + suffix, replacement_base + suffix)
        text = re.sub(pattern, repl, text, flags=re.IGNORECASE)
    return text

# %%
df1['full_text'] = df1['full_text'].apply(apply_degendering)

# %% [markdown]
# ### Second Dataset

# %%
df2 = df2[['full_text', 'applicant_gender']]
df2 = df2.rename(columns={'applicant_gender':'label'})
df2['full_text'] = df2['full_text'].str.lower()

# %%
df2['full_text'] = df2['full_text'].apply(apply_degendering)

# %% [markdown]
# # Combine Data

# %%
apply_degendering("he is the husband's brother's uncle's actor and fireman. he is a male and is a father of three sons. (he'll) be a great doctor. his helped him, and himself.")
# Out:
# "she is the wife's sister's aunt's actress and firewoman. she is a female and is a mother of three daughters. (she'll) be a great doctor. her helped her, and herself."

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
gender_label_mapping = {
    'F':0,
    'female':0,
    'M':1,
    'male':1
}

# %%
df['label'] = df['label'].replace(gender_label_mapping)
# Out:
# <ipython-input-16-cc45885305bc>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['label'] = df['label'].replace(gender_label_mapping)

# %%
#df.to_csv('../data/combined_letters_degendered.csv', index=False)

# %% [markdown]
# # Create Gendered Mapping Dictionary

# %%
# raw_pairs
# Out:
# {'masculine': 'feminine',
#  'masculinely': 'femininely',
#  'masculinity': 'femininity',
#  'masculism': 'feminism',
#  'masculinist': 'feminist',
#  'patriarch': 'matriarch',
#  'patriarchal': 'matriarchal',
#  'male': 'female',
#  'males': 'females',
#  'maleness': 'femaleness',
#  'boy': 'girl',
#  'boys': 'girls',
#  'gamine': 'girly',
#  'boyhood': 'girlhood',
#  'boyish': 'girlish',
#  'boyishly': 'girlishly',
#  'boyishness': 'girlishness',
#  'man': 'woman',
#  'men': 'women',
#  'manhood': 'womanhood',
#  'manliness': 'womanliness',
#  'manly': 'womanly',
#  'virile': 'uxorially',
#  'virility': 'milkiness',
#  'sir': 'madam',
#  'sirs': 'madams',
#  'widower': 'widow',
#  'widowers': 'widows',
#  'mr': 'ms',
#  'mister': 'ms',
#  'gentleman': 'damsel',
#  'gentlemen': 'damsels',
#  'gentlemanlike': 'ladylike',
#  'lord': 'lady',
#  'lords': 'ladies',
#  'groom': 'bride',
#  'grooms': 'brides',
#  'bridegroom': 'bride',
#  'bridegrooms': 'brides',
#  'best man': 'bridesmaid',
#  'best men': 'bridesmaids',
#  'fiance': 'fiancee',
#  'fiancé': 'fiancée',
#  'fiances': 'fiancees',
#  'fiancés': 'fiancées',
#  'housewifely': 'butch',
#  'bloke': 'girl',
#  'blokes': 'girls',
#  'dude': 'girlie',
#  'dudes': 'girlies',
#  'fella': 'chick',
#  'fellas': 'chicks',
#  'chap': 'lassie',
#  'chaps': 'lassies',
#  'guy': 'gal',
#  'guys': 'gals',
#  'lad': 'lass',
#  'lads': 'lasses',
#  'macho': 'diva',
#  'machos': 'divas',
#  'actor': 'actress',
#  'actors': 'actresses',
#  'waiter': 'waitress',
#  'waiters': 'waitresses',
#  'king': 'queen',
#  'kings': 'queens',
#  'prince': 'princess',
#  'princes': 'princesses',
#  'monk': 'nun',
#  'monks': 'nuns',
#  'brethren': 'nuns',
#  'monastery': 'convent',
#  'friary': 'nunnery',
#  'count': 'countess',
#  'counts': 'countesses',
#  'wizard': 'witch',
#  'wizards': 'witches',
#  'priest': 'priestess',
#  'priests': 'priestesses',
#  'prophet': 'prophetess',
#  'prophets': 'prophetesses',
#  'patron': 'patroness',
#  'patrons': 'patronesses',
#  'host': 'hostess',
#  'hosts': 'hostesses',
#  'viscount': 'viscountess',
#  'viscounts': 'viscountesses',
#  'shepherd': 'shepherdess',
#  'shepherds': 'shepherdesses',
#  'steward': 'stewardess',
#  'stewards': 'stewardesses',
#  'heir': 'heiress',
#  'heirs': 'heiresses',
#  'baron': 'baroness',
#  'barons': 'baronesses',
#  'abbot': 'abbess',
#  'abbots': 'abbesses',
#  'emperor': 'empress',
#  'emperors': 'empresses',
#  'traitor': 'traitress',
#  'traitors': 'traitresses',
#  'duke': 'duchess',
#  'dukes': 'duchesses',
#  'enchanter': 'enchantress',
#  'enchanters': 'enchantresses',
#  'songster': 'songstress',
#  'songsters': 'songstresses',
#  'hero': 'heroine',
#  'heroes': 'heroines',
#  'sultan': 'sultana',
#  'sultans': 'sultanas',
#  'czar': 'czarina',
#  'czars': 'czarinas',
#  'signor': 'signora',
#  'signors': 'signoras',
#  'benefactor': 'benefactress',
#  'benefactors': 'benefactresses',
#  'hunter': 'huntress',
#  'tempter': 'temptress',
#  'tempters': 'temptresses',
#  'master': 'mistress',
#  'masters': 'mistresses',
#  'manservant': 'maidservant',
#  'manservants': 'maidservants',
#  'landlord': 'landlady',
#  'landlords': 'landladies',
#  'countryman': 'countrywoman',
#  'countrymen': 'countrywomen',
#  'milkman': 'milkmaid',
#  'milkmen': 'milkmaids',
#  'giant': 'giantess',
#  'giants': 'giantesses',
#  'mayor': 'mayoress',
#  'mayors': 'mayoresses',
#  'conductor': 'conductress',
#  'conductors': 'conductresses',
#  'god': 'goddess',
#  'gods': 'goddesses',
#  'merman': 'mermaid',
#  'mermen': 'mermaids',
#  'oarsman': 'oarswoman',
#  'oarsmen': 'oarswomen',
#  'bellboy': 'chambermaid',
#  'bellboys': 'chambermaids',
#  'dairyman': 'dairymaid',
#  'dairymen': 'dairymaids',
#  'schoolmaster': 'schoolmistress',
#  'schoolmasters': 'schoolmistresses',
#  'headmaster': 'headmistress',
#  'proprietor': 'proprietress',
#  'proprietors': 'proprietresses',
#  'ambassador': 'ambassadress',
#  'ambassadors': 'ambassadresses',
#  'adventurer': 'adventuress',
#  'adventurers': 'adventuresses',
#  'protector': 'protectress',
#  'protectors': 'protectresses',
#  'seducer': 'seductress',
#  'seducers': 'seductresses',
#  'sculptor': 'sculptress',
#  'sculptors': 'sculptresses',
#  'congressman': 'congresswoman',
#  'congressmen': 'congresswomen',
#  'sorcerer': 'sorceress',
#  'sorcerers': 'sorceresses',
#  'launderer': 'laundress',
#  'launderers': 'laundresses',
#  'anchorite': 'anchoress',
#  'anchorites': 'anchoresses',
#  'procurer': 'procuress',
#  'procurers': 'procuresses',
#  'elector': 'electress',
#  'electors': 'electresses',
#  'adulterer': 'adulteress',
#  'adulterers': 'adulteresses',
#  'doorman': 'doorwoman',
#  'doormen': 'doorwomen',
#  'policeman': 'policewoman',
#  'policemen': 'policewomen',
#  'fireman': 'firewoman',
#  'firemen': 'firewomen',
#  'businessman': 'businesswoman',
#  'businessmen': 'businesswomen',
#  'barman': 'barmaid',
#  'barmen': 'barmaids',
#  'mailman': 'mailwoman',
#  'mailmen': 'mailwomen',
#  'postman': 'postwoman',
#  'postmen': 'postwoman',
#  'salesman': 'saleswoman',
#  'salesmen': 'saleswomen',
#  'cowboy': 'cowgirl',
#  'cowboys': 'cowgirls',
#  'schoolboy': 'schoolgirl',
#  'schoolboys': 'schoolgirls',
#  'chairman': 'chairwoman',
#  'chairmen': 'chairwomen',
#  'englishman': 'englishwoman',
#  'englishmen': 'englishwomen',
#  'spokesman': 'spokeswoman',
#  'spokesmen': 'spokeswomen',
#  'councilman': 'councilwoman',
#  'councilmen': 'councilwomen',
#  'choirboy': 'choirgirl',
#  'choirboys': 'choirgirls',
#  'playboy': 'playgirl',
#  'playboys': 'playgirls',
#  'homeboy': 'homegirl',
#  'homeboys': 'homegirls',
#  'madman': 'madwoman',
#  'madmen': 'madwomen',
#  'anchorman': 'anchorwoman',
#  'anchormen': 'anchorwomen',
#  'sportsman': 'sportswoman',
#  'sportsmen': 'sportswomen',
#  'cameraman': 'camerawoman',
#  'cameramen': 'camerawomen',
#  'fisherman': 'fisherwoman',
#  'fishermen': 'fisherwomen',
#  'serviceman': 'servicewoman',
#  'servicemen': 'servicewomen',
#  'churchman': 'churchwoman',
#  'churchmen': 'churchwomen',
#  'clergyman': 'clergywoman',
#  'clergymen': 'clergywomen',
#  'craftsman': 'craftswoman',
#  'craftsmen': 'craftswomen',
#  'superman': 'superwoman',
#  'supermen': 'superwomen',
#  'nobleman': 'noblewoman',
#  'noblemen': 'noblewomen',
#  'horseman': 'horsewoman',
#  'horsemen': 'horsewomen',
#  'stuntman': 'stuntwoman',
#  'stuntmen': 'stuntwomen',
#  'townsman': 'townswoman',
#  'townsmen': 'townswomen',
#  'statesman': 'stateswoman',
#  'statesmen': 'stateswomen',
#  'foreman': 'forewoman',
#  'foremen': 'forewomen',
#  'kinsman': 'kinswoman',
#  'kinsmen': 'kinswomen',
#  'bondman': 'bondwoman',
#  'bondmen': 'bondwomen',
#  'bondsman': 'bondswoman',
#  'bondsmen': 'bondswomen',
#  'handyman': 'handywoman',
#  'handymen': 'handywomen',
#  'henchman': 'handmaid',
#  'henchmen': 'handmaids',
#  'strongman': 'strongwoman',
#  'strongmen': 'strongwomen',
#  'charman': 'charwoman',
#  'charmen': 'charwomen',
#  'tailor': 'needlewoman',
#  'tailors': 'needlewomen',
#  'newsman': 'newswoman',
#  'newsmen': 'newswomen',
#  'father': 'mother',
#  'fathers': 'mothers',
#  'brother': 'sister',
#  'brothers': 'sisters',
#  'husband': 'wife',
#  'husbands': 'wives',
#  'housewife': 'househusband',
#  'housewives': 'househusbands',
#  'hubby': 'wifey',
#  'hubbies': 'wifeys',
#  'son': 'daughter',
#  'sons': 'daughters',
#  'dad': 'mom',
#  'dads': 'moms',
#  'papa': 'mama',
#  'papas': 'mamas',
#  'daddy': 'mommy',
#  'daddies': 'mommies',
#  'pa': 'ma',
#  'paternity': 'maternity',
#  'paternally': 'maternally',
#  'paternal': 'maternal',
#  'fatherhood': 'motherhood',
#  'brotherhood': 'sisterhood',
#  'fraternity': 'sorority',
#  'fraternities': 'sororities',
#  'fraternal': 'sisterly',
#  'fraternally': 'sisterly',
#  'brotherly': 'sisterly',
#  'fatherly': 'motherly',
#  'grandfatherly': 'grandmotherly',
#  'fathered': 'mothered',
#  'stepfather': 'stepmother',
#  'stepfathers': 'stepmothers',
#  'stepbrother': 'stepsister',
#  'stepbrothers': 'stepsisters',
#  'stepson': 'stepdaughter',
#  'stepsons': 'stepdaughters',
#  'grandfather': 'grandmother',
#  'grandfathers': 'grandmothers',
#  'grandpa': 'grandma',
#  'grandpas': 'grandmas',
#  'grandson': 'granddaughter',
#  'grandsons': 'granddaughters',
#  'nephew': 'niece',
#  'nephews': 'nieces',
#  'brother-in-law': 'sister-in-law',
#  'brothers-in-law': 'sisters-in-law',
#  'father-in-law': 'mother-in-law',
#  'fathers-in-law': 'mothers-in-law',
#  'son-in-law': 'daughter-in-law',
#  'sons-in-law': 'daughters-in-law',
#  'uncle': 'aunt',
#  'uncles': 'aunts',
#  'boyfriend': 'girlfriend',
#  'boyfriends': 'girlfriends',
#  'ancestor': 'ancestress',
#  'ancestors': 'ancestresses',
#  'bachelor': 'maiden',
#  'bachelors': 'maidens',
#  'testosterone': 'estrogen',
#  'testosterones': 'estrogens',
#  'penis': 'vagina',
#  'penises': 'vaginas',
#  'prostate': 'ovarian',
#  'testicles': 'uteruses',
#  'testicle': 'uterus',
#  'sperm': 'ovary',
#  'he': 'she',
#  'him': 'her',
#  'his': 'her',
#  'himself': 'herself',
#  "he'd": "she'd",
#  "he'll": "she'll",
#  'gay': 'lesbian',
#  'gays': 'lesbians',
#  'homosexuality': 'lesbianism',
#  'victor': 'victress',
#  'victors': 'victresses',
#  'murderer': 'murderess',
#  'murderers': 'murderesses',
#  'millionaire': 'millionairess',
#  'millionaires': 'millionairesses',
#  'manager': 'manageress',
#  'managers': 'manageresses',
#  'governor': 'governoress',
#  'governors': 'governoresses',
#  'director': 'directress',
#  'directors': 'directresses',
#  'inventor': 'inventress',
#  'inventors': 'inventresses',
#  'instructor': 'instructress',
#  'instructors': 'instructresses',
#  'childminder': 'nursemaid',
#  'childminders': 'nursemaids',
#  'barbershop': 'hairdresser',
#  'beard': 'hair',
#  'beards': 'hair',
#  'juryman': 'juror',
#  'jurymen': 'jurors',
#  'newsboy': 'newspaper carrier',
#  'newsboys': 'newspaper carriers',
#  'paperboy': 'newspaper carrier',
#  'paperboys': 'newspaper carriers',
#  'newspaperman': 'newspaperwoman',
#  'newspapermen': 'newspaperwomen',
#  'divo': 'diva',
#  'brideprice': 'dowry',
#  'airmen': 'airwomen',
#  'andropause': 'menopause',
#  'househusbands': 'housewives',
#  'adultors': 'adultresses',
#  'andrology': 'obstetrics',
#  'marquis': 'marchioness',
#  'stallion': 'mare',
#  'semen': 'female_ejaculation',
#  'androgen': 'estrogen',
#  'godfather': 'godmother',
#  'cialis': 'viagra',
#  'beau': 'belle',
#  'stud': 'minx',
#  'bull': 'cow',
#  'beaus': 'belles',
#  'adultor': 'adultress',
#  'rooster': 'hen',
#  'ballet_dancer': 'ballerina',
#  'colts': 'fillies',
#  'suitor': 'suitress',
#  'masseurs': 'masseuses',
#  'deer': 'doe',
#  'busboys': 'busgirls',
#  'studs': 'minxes',
#  'mentleman': 'lady',
#  'baritone': 'mezzo',
#  'paramour': 'mistress',
#  'male_host': 'hostess',
#  'menservants': 'maids',
#  'mr.': 'mrs.',
#  'headmasters': 'headmistresses',
#  'airman': 'airwoman',
#  'househusband': 'housewife',
#  'colt': 'filly',
#  'lions': 'lionesses',
#  'masseur': 'masseuse',
#  'bulls': 'cows',
#  'lion': 'lioness',
#  'prostatic_utricle': 'womb',
#  'gents': 'ladies',
#  'gelding': 'mare',
#  'roosters': 'hens',
#  'stailor': "seamstress'",
#  'busboy': 'busgirl',
#  'heros': 'heroines'}

# %%
# raw_pairs_df = pd.DataFrame(list(raw_pairs.items()), columns=['male term', 'female term'])

# %%
# raw_pairs_df.to_csv('../data/gendered_term_mapping.csv', index=False)
