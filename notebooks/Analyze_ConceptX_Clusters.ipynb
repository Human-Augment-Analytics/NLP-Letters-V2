# %%
# !pip install dill
# Out:
# Collecting dill
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# %%
os.chdir('/content/drive/My Drive/NLP-Letters-V2/notebooks/')

# %%
df = pd.read_csv('../data/conceptx_data/clusters-50.txt', sep='\|\|\|')
df.columns = ['Word', 'WordID', 'SentID', 'TokenID', 'ClusterID']
# Out:
# <ipython-input-26-e31aada38d5c>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('../data/conceptx_data/clusters-50.txt', sep='\|\|\|')

# %%
df[df['ClusterID'] == 42]
# Out:
#       Word WordID  SentID  TokenID  ClusterID
# 23234  dr.      1      28        7         42
# 23235  ms.      1      48        2         42
# 23236  dr.      2      57        0         42
# 23237  dr.      3      62        3         42
# 23238  mr.      1      69        6         42
# 23239  dr.      4      70        2         42
# 23240  mr.      2     102        2         42
# 23241  dr.      5     115        4         42
# 23242  mr.      3     144        0         42
# 23243  dr.      6     165        9         42
# 23244  dr.      7     165       21         42
# 23245  ms.      2     169       12         42
# 23246  dr.      8     175       10         42
# 23247  dr.      9     176        0         42
# 23248  dr.     10     180        0         42
# 23249  dr.     11     202        3         42
# 23250  mr.      4     209       39         42
# 23251  mr.      5     219       15         42
# 23252  mr.      6     233        0         42
# 23253  ms.      3     255       10         42
# 23254  dr.     12     258        1         42
# 23255  dr.     13     260       14         42
# 23256  dr.     14     269        3         42
# 23257  dr.     15     272        8         42
# 23258  ms.      4     273        0         42
# 23259  mr.      7     313        9         42
# 23260  mr.      8     347        9         42
# 23261  dr.     16     364        1         42
# 23262  dr.     17     366        0         42
# 23263  dr.     18     370        0         42
# 23264  dr.     19     419        0         42
# 23265  ms.      5     422        0         42
# 23266  mr.      9     423        5         42
# 23267  mr.     10     449       32         42
# 23268  mr.     11     472        2         42
# 23269  mr.     12     528        3         42
# 23270  ms.      6     536        0         42
# 23271  ms.      7     549        9         42
# 23272  dr.     20     592       12         42
# 23273  dr.     21     623        3         42
# 23274  mr.     13     630        4         42
# 23275  dr.     22     659        2         42
# 23276  dr.     23     665        2         42
# 23277  ms.      8     744        0         42
# 23278  dr.     24     782        0         42
# 23279  dr.     25     809        0         42
# 23280  mr.     14     826        0         42
# 23281  dr.     26     832       16         42
# 23282  mr.     15     848        4         42
# 23283  mr.     16     859        0         42
# 23284  dr.     27     919        0         42
# 23285  dr.     28     923       11         42
# 23286  dr.     29     952        6         42
# 23287  mr.     17     981       26         42
# 23288  ms.      9     984        3         42
# 23289  ms.     10     988        7         42
